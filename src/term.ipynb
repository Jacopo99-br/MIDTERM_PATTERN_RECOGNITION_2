# %%
# !nvidia-smi
# Out:
# Tue Jul 21 17:14:24 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   46C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# %%bash
# # 1. Spostati nella cartella root /content
# # 1. Vai nella cartella /content
# cd /content
#
# # 2. Elimina TUTTO il contenuto di /content per lasciarla completamente vuota
# rm -rf /content/* /content/.* 2>/dev/null
#
# # 3. Ora clona di nuovo usando il tuo token o la repo pubblica
# git clone https://github.com/Jacopo99-br/MIDTERM_PATTERN_RECOGNITION_2 .
# Out:
# Cloning into '.'...

# %%
# %%bash
# ls -la /content
# Out:
# total 140
# drwxr-xr-x 1 root root  4096 Jul 21 17:36 .
# drwxr-xr-x 1 root root  4096 Jul 21 17:11 ..
# -rw-r--r-- 1 root root 26402 Jul 21 17:36 benchmark_plots.png
# -rw-r--r-- 1 root root  1093 Jul 21 17:36 CMakeLists.txt
# drwxr-xr-x 8 root root  4096 Jul 21 17:36 .git
# -rw-r--r-- 1 root root    87 Jul 21 17:36 .gitignore
# drwxr-xr-x 2 root root  4096 Jul 21 17:36 include
# -rw-r--r-- 1 root root 55695 Jul 21 17:36 multiple_queries_performance.png
# -rw-r--r-- 1 root root 22640 Jul 21 17:36 single_query_performance.png
# drwxr-xr-x 2 root root  4096 Jul 21 17:36 src
